# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('GSM5493629_DCIS1.st.count.matrix.csv', index_col=0)
# Out:
#              AAACAAGTATCTCCCA.1  AAACATTTCCCGGATT.1  AAACCTAAGCAGCCGG.1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
# ...                         ...                 ...                 ...
# AC233755.2                    0                   0                   0
# AC233755.1                    0                   0                   0
# AC240274.1                    0                   0                   0
# AC213203.1                    0                   0                   0
# FAM231C                       0                   0                   0
#
#              AAACGAAGAACATACC.1  AAACGAGACGGTTGAT.1  AAACGGGCGTACGGGT.1  \
# ...

# %%
pd.read_csv('GSM5493628_DCIS1.sc.count.matrix.csv', index_col=0)
# Out:
#              AAACCTGAGATCCCGC  AAACCTGAGGGATGGG  AAACCTGCATAACCTG  \
# MIR1302-2HG                 0                 0                 0
# FAM138A                     0                 0                 0
# OR4F5                       0                 0                 0
# AL627309.1                  0                 0                 0
# AL627309.3                  0                 0                 0
# ...                       ...               ...               ...
# AC233755.2                  0                 0                 0
# AC233755.1                  0                 0                 0
# AC240274.1                  0                 0                 0
# AC213203.1                  0                 0                 0
# FAM231C                     0                 0                 0
#
#              AAACCTGGTTGTTTGG  AAACCTGTCACAATGC  AAACCTGTCACTCTTA  \
# MIR1302-2HG                 0                 0                 0
# ...
